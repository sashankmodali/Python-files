# %%
import numpy as np
from matplotlib import pyplot as plt

step=0.000003
x = np.arange(-1,1+step,step)

y = x**2*np.sin(1/x**2)

print(len(y))

diff = (y[1:]-y[0:len(y)-1])/(x[1:]-x[0:len(y)-1])
delta = x[1:]
y2 = 2*x*np.sin(1/x**2) - 2/x**2*np.cos(1/x**2)

# print(x)
# print(y)

print(0+0.1-0.1)

print(x[len(x)//2-1:len(x)//2+2])
print(y[len(x)//2-1:len(x)//2+2])
plt.figure()
plt.plot(x,y, label="1")
# plt.plot(x,y2, label="2")
plt.legend()
plt.title("Riemann Integrability - function");
plt.show();

plt.figure()
# plt.plot(x,y, label="1")
# plt.plot(x,y2, label="2")
plt.plot(delta[3*len(delta)//8:5*len(delta)//8],diff[3*len(delta)//8:5*len(delta)//8], label="1")
plt.legend()
plt.title("Riemann Integrability -slope");
plt.show();
# Out:
# 666668
# 0.0
# [-1.00000825e-06  1.99999175e-06  4.99999175e-06]
# [ 9.01172897e-13  3.14910936e-12 -2.41454362e-11]
